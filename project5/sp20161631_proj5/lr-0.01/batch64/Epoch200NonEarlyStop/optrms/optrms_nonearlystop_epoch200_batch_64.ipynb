# %% [markdown]
# # Import modules

# %%
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.utils.vis_utils import model_to_dot
from IPython.display import SVG
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
# Out:
# Using TensorFlow backend.

# %%
from keras.constraints import maxnorm
from keras.callbacks import LearningRateScheduler
from keras import regularizers
import numpy as np
from keras.preprocessing.image import ImageDataGenerator

# from keras.callbacks import TensorBoard


# !pip install tensorboardcolab
from tensorboardcolab import *
# Out:
# Requirement already satisfied: tensorboardcolab in /usr/local/lib/python3.6/dist-packages (0.0.22)

# %% [markdown]
# # Tuning parameters and callbacks

# %%
def tuning_parameters():
  global epochs
  global learning_rate
  global batch_size
  global num_classes
  
  epochs = 200
  
  learning_rate=0.01

  batch_size = 64
  
  num_classes = 10

# %%
def init_callbacks():
  my_callbacks = []
  
#   from keras.callbacks import EarlyStopping
#   early_stopping = EarlyStopping(patience = 20)
  
#   my_callbacks.append(early_stopping)
  
  tbc=TensorBoardColab()

  my_callbacks.append(TensorBoardColabCallback(tbc))
  
  return my_callbacks

# %%
tuning_parameters()
my_callbacks = init_callbacks()
# Out:
# Wait for 8 seconds...
# TensorBoard link:
# https://474b4baf.ngrok.io

# %%
# callbacks[0]

# %% [markdown]
# # Data

# %% [markdown]
# ## Plot image

# %%
def plot_images(x, y_true, y_pred=None, size=(5, 5)):
    assert len(x) == len(y_true) == size[0] * size[1]
    
    fig, axes = plt.subplots(size[0], size[1])
    fig.subplots_adjust(hspace=0.5, wspace=0.1)

    for i, ax in enumerate(axes.flat):
        if x[i].shape[-1] == 1:
          ax.imshow(x[i].reshape(x[i].shape[0], x[i].shape[1]))
        else:
          ax.imshow(x[i])

        if y_pred is None:
            xlabel = "True: {0}".format(y_true[i].argmax())
        else:
            xlabel = "True: {0}, Pred: {1}".format(y_true[i].argmax(), 
                                                   y_pred[i].argmax())

        ax.set_xlabel(xlabel)
        
        ax.set_xticks([])
        ax.set_yticks([])

    plt.show()

# %% [markdown]
# ## Load dataset

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
len(x_train.shape)
# Out:
# 4

# %%
# plotx_test[0]

# %% [markdown]
# ## Reshaping the data

# %%
if len(x_train.shape) < 4:
  x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
  x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

x_train /= 255.0
x_test /= 255.0

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# print(mean, std)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## Applying One hot encoding for the data

# %%
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
# plot_images(x_test[:10],y_test[:10])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-39-6702bcbe5b24> in <module>()
# ----> 1 plot_images(x_test[:10],y_test[:10])
#
# <ipython-input-7-cec24243eee3> in plot_images(x, y_true, y_pred, size)
#       1 def plot_images(x, y_true, y_pred=None, size=(5, 5)):
# ----> 2     assert len(x) == len(y_true) == size[0] * size[1]
#       3
#       4     fig, axes = plt.subplots(size[0], size[1])
#       5     fig.subplots_adjust(hspace=0.5, wspace=0.1)
#
# AssertionError:

# %% [markdown]
# ## Show data

# %%
plot_images(x_train[:25], y_train[:25])

# %% [markdown]
# # Creating the DNN model

# %%
x_train.shape[1:]
# Out:
# (32, 32, 3)

# %%
def make_model():
  global model
  weight_decay = 1e-4
  model = Sequential()
  model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train.shape[1:]))
  model.add(Activation('elu'))
  model.add(BatchNormalization())
  model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('elu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.2))

  model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('elu'))
  model.add(BatchNormalization())
  model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('elu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.3))

  model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('elu'))
  model.add(BatchNormalization())
  model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('elu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.4))

  model.add(Flatten())
  
  model.add(Dense(num_classes, activation='softmax'))

# %%
def lr_schedule(epoch):
    lrate = 0.01
    if epoch > 75:
        lrate = 0.005
    if epoch > 100:
        lrate = 0.003
    return lrate

# %%
make_model()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# opt_rms = keras.optimizers.rmsprop(lr=0.001,decay=1e-6)

# model.compile(loss='categorical_crossentropy', optimizer=opt_rms, metrics=['accuracy'])

# model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),\
#                     steps_per_epoch=x_train.shape[0] // batch_size,epochs=125,\
#                     verbose=1,validation_data=(x_test,y_test),
#                     callbacks=[LearningRateScheduler(lr_schedule)])

# %% [markdown]
# ## Visualization the model

# %%
SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# ## Optimizer

# %%
# optimizer = keras.optimizers.SGD(lr=learning_rate)
opt_rms = keras.optimizers.rmsprop(lr=0.01,decay=1e-6)

# %% [markdown]
# ## Compiling the model

# %%
model.compile(loss=keras.losses.categorical_crossentropy, 
              optimizer=opt_rms,
              metrics=['accuracy'])

# %% [markdown]
# ## Training the model

# %%
history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test),
          callbacks=my_callbacks)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/200
# 50000/50000 [==============================] - 14s 274us/step - loss: 2.7013 - acc: 0.3109 - val_loss: 8.2295 - val_acc: 0.1664
# Epoch 2/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.4924 - acc: 0.5401 - val_loss: 3.3408 - val_acc: 0.3342
# Epoch 3/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.2877 - acc: 0.6303 - val_loss: 1.9966 - val_acc: 0.4824
# Epoch 4/200
# 50000/50000 [==============================] - 11s 220us/step - loss: 1.2343 - acc: 0.6563 - val_loss: 1.7634 - val_acc: 0.5466
# Epoch 5/200
# 50000/50000 [==============================] - 11s 221us/step - loss: 1.2049 - acc: 0.6732 - val_loss: 2.0253 - val_acc: 0.4897
# Epoch 6/200
# 50000/50000 [==============================] - 11s 220us/step - loss: 1.1904 - acc: 0.6800 - val_loss: 1.2595 - val_acc: 0.6584
# Epoch 7/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.1840 - acc: 0.6849 - val_loss: 1.7989 - val_acc: 0.5147
# Epoch 8/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.1749 - acc: 0.6942 - val_loss: 1.7830 - val_acc: 0.5433
# Epoch 9/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.1711 - acc: 0.6946 - val_loss: 1.4548 - val_acc: 0.6379
# Epoch 10/200
# 50000/50000 [==============================] - 11s 221us/step - loss: 1.1595 - acc: 0.6982 - val_loss: 1.6620 - val_acc: 0.5766
# Epoch 11/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.1574 - acc: 0.7020 - val_loss: 1.4270 - val_acc: 0.6260
# Epoch 12/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.1525 - acc: 0.7023 - val_loss: 1.3149 - val_acc: 0.6540
# Epoch 13/200
# 50000/50000 [==============================] - 11s 220us/step - loss: 1.1541 - acc: 0.7052 - val_loss: 1.1088 - val_acc: 0.7236
# Epoch 14/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.1552 - acc: 0.7028 - val_loss: 1.2102 - val_acc: 0.6764
# Epoch 15/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.1446 - acc: 0.7061 - val_loss: 1.2447 - val_acc: 0.6815
# Epoch 16/200
# 50000/50000 [==============================] - 11s 220us/step - loss: 1.1420 - acc: 0.7069 - val_loss: 1.4558 - val_acc: 0.6235
# Epoch 17/200
# 50000/50000 [==============================] - 11s 221us/step - loss: 1.1375 - acc: 0.7099 - val_loss: 1.0936 - val_acc: 0.7253
# Epoch 18/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.1332 - acc: 0.7125 - val_loss: 2.0535 - val_acc: 0.5110
# Epoch 19/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.1373 - acc: 0.7099 - val_loss: 1.6212 - val_acc: 0.5474
# Epoch 20/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.1269 - acc: 0.7143 - val_loss: 1.1848 - val_acc: 0.6846
# Epoch 21/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.1191 - acc: 0.7166 - val_loss: 1.0824 - val_acc: 0.7294
# Epoch 22/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.1217 - acc: 0.7162 - val_loss: 1.6177 - val_acc: 0.6422
# Epoch 23/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.1189 - acc: 0.7141 - val_loss: 1.1026 - val_acc: 0.7208
# Epoch 24/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.1239 - acc: 0.7157 - val_loss: 1.1448 - val_acc: 0.7079
# Epoch 25/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.1211 - acc: 0.7179 - val_loss: 1.3471 - val_acc: 0.6508
# Epoch 26/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.1143 - acc: 0.7170 - val_loss: 1.4673 - val_acc: 0.6352
# Epoch 27/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.1097 - acc: 0.7198 - val_loss: 2.0798 - val_acc: 0.4651
# Epoch 28/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.1163 - acc: 0.7188 - val_loss: 1.8767 - val_acc: 0.5458
# Epoch 29/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.1119 - acc: 0.7186 - val_loss: 1.6695 - val_acc: 0.6040
# Epoch 30/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.1080 - acc: 0.7193 - val_loss: 1.2348 - val_acc: 0.6923
# Epoch 31/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.1045 - acc: 0.7216 - val_loss: 1.6080 - val_acc: 0.6055
# Epoch 32/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.1052 - acc: 0.7209 - val_loss: 1.7034 - val_acc: 0.5711
# Epoch 33/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0960 - acc: 0.7229 - val_loss: 1.1786 - val_acc: 0.6982
# Epoch 34/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.1094 - acc: 0.7194 - val_loss: 1.5514 - val_acc: 0.5925
# Epoch 35/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.0932 - acc: 0.7246 - val_loss: 1.2523 - val_acc: 0.6748
# Epoch 36/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0958 - acc: 0.7235 - val_loss: 1.9495 - val_acc: 0.5502
# Epoch 37/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0979 - acc: 0.7227 - val_loss: 1.5715 - val_acc: 0.5995
# Epoch 38/200
# 50000/50000 [==============================] - 11s 220us/step - loss: 1.0962 - acc: 0.7242 - val_loss: 1.6237 - val_acc: 0.5776
# Epoch 39/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0912 - acc: 0.7220 - val_loss: 1.0836 - val_acc: 0.7241
# Epoch 40/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0895 - acc: 0.7226 - val_loss: 1.1917 - val_acc: 0.6924
# Epoch 41/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0894 - acc: 0.7259 - val_loss: 1.5214 - val_acc: 0.6337
# Epoch 42/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.0857 - acc: 0.7249 - val_loss: 1.4054 - val_acc: 0.6016
# Epoch 43/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0867 - acc: 0.7241 - val_loss: 1.1371 - val_acc: 0.7121
# Epoch 44/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0832 - acc: 0.7277 - val_loss: 1.7848 - val_acc: 0.5545
# Epoch 45/200
# 50000/50000 [==============================] - 11s 223us/step - loss: 1.0924 - acc: 0.7225 - val_loss: 1.2462 - val_acc: 0.6868
# Epoch 46/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0846 - acc: 0.7261 - val_loss: 1.3535 - val_acc: 0.6578
# Epoch 47/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0867 - acc: 0.7243 - val_loss: 1.4874 - val_acc: 0.6044
# Epoch 48/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0863 - acc: 0.7245 - val_loss: 1.3640 - val_acc: 0.6633
# Epoch 49/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0829 - acc: 0.7264 - val_loss: 1.0720 - val_acc: 0.7316
# Epoch 50/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.0841 - acc: 0.7277 - val_loss: 1.1253 - val_acc: 0.7101
# Epoch 51/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0811 - acc: 0.7287 - val_loss: 1.3074 - val_acc: 0.6474
# Epoch 52/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0757 - acc: 0.7308 - val_loss: 1.3390 - val_acc: 0.6440
# Epoch 53/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0806 - acc: 0.7267 - val_loss: 1.1586 - val_acc: 0.7116
# Epoch 54/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0852 - acc: 0.7261 - val_loss: 1.7028 - val_acc: 0.5702
# Epoch 55/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0774 - acc: 0.7289 - val_loss: 1.1279 - val_acc: 0.7250
# Epoch 56/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.0764 - acc: 0.7293 - val_loss: 1.2112 - val_acc: 0.6879
# Epoch 57/200
# 50000/50000 [==============================] - 11s 220us/step - loss: 1.0702 - acc: 0.7321 - val_loss: 1.0430 - val_acc: 0.7386
# Epoch 58/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0729 - acc: 0.7302 - val_loss: 1.2686 - val_acc: 0.6733
# Epoch 59/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0705 - acc: 0.7298 - val_loss: 1.4461 - val_acc: 0.6113
# Epoch 60/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0757 - acc: 0.7282 - val_loss: 1.5635 - val_acc: 0.5909
# Epoch 61/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0679 - acc: 0.7302 - val_loss: 1.2833 - val_acc: 0.6745
# Epoch 62/200
# 50000/50000 [==============================] - 11s 223us/step - loss: 1.0735 - acc: 0.7289 - val_loss: 1.3701 - val_acc: 0.6372
# Epoch 63/200
# 50000/50000 [==============================] - 12s 230us/step - loss: 1.0621 - acc: 0.7320 - val_loss: 1.1108 - val_acc: 0.7063
# Epoch 64/200
# 50000/50000 [==============================] - 12s 232us/step - loss: 1.0659 - acc: 0.7289 - val_loss: 1.6014 - val_acc: 0.5676
# Epoch 65/200
# 50000/50000 [==============================] - 12s 231us/step - loss: 1.0608 - acc: 0.7305 - val_loss: 1.5481 - val_acc: 0.6048
# Epoch 66/200
# 50000/50000 [==============================] - 12s 232us/step - loss: 1.0668 - acc: 0.7319 - val_loss: 1.3115 - val_acc: 0.6774
# Epoch 67/200
# 50000/50000 [==============================] - 11s 230us/step - loss: 1.0692 - acc: 0.7303 - val_loss: 0.9548 - val_acc: 0.7649
# Epoch 68/200
# 50000/50000 [==============================] - 12s 230us/step - loss: 1.0620 - acc: 0.7321 - val_loss: 1.1344 - val_acc: 0.7039
# Epoch 69/200
# 50000/50000 [==============================] - 11s 230us/step - loss: 1.0598 - acc: 0.7331 - val_loss: 1.1260 - val_acc: 0.7118
# Epoch 70/200
# 50000/50000 [==============================] - 11s 230us/step - loss: 1.0664 - acc: 0.7301 - val_loss: 1.1253 - val_acc: 0.7043
# Epoch 71/200
# 50000/50000 [==============================] - 12s 231us/step - loss: 1.0556 - acc: 0.7331 - val_loss: 1.1262 - val_acc: 0.7037
# Epoch 72/200
# 50000/50000 [==============================] - 12s 232us/step - loss: 1.0498 - acc: 0.7344 - val_loss: 1.0547 - val_acc: 0.7357
# Epoch 73/200
# 50000/50000 [==============================] - 12s 235us/step - loss: 1.0582 - acc: 0.7302 - val_loss: 1.5445 - val_acc: 0.6236
# Epoch 74/200
# 50000/50000 [==============================] - 11s 230us/step - loss: 1.0590 - acc: 0.7292 - val_loss: 1.1178 - val_acc: 0.7124
# Epoch 75/200
# 50000/50000 [==============================] - 12s 230us/step - loss: 1.0591 - acc: 0.7316 - val_loss: 1.4277 - val_acc: 0.6091
# Epoch 76/200
# 50000/50000 [==============================] - 11s 230us/step - loss: 1.0570 - acc: 0.7315 - val_loss: 1.2575 - val_acc: 0.6853
# Epoch 77/200
# 50000/50000 [==============================] - 12s 231us/step - loss: 1.0493 - acc: 0.7309 - val_loss: 1.0688 - val_acc: 0.7189
# Epoch 78/200
# 50000/50000 [==============================] - 12s 232us/step - loss: 1.0492 - acc: 0.7332 - val_loss: 1.3610 - val_acc: 0.6300
# Epoch 79/200
# 50000/50000 [==============================] - 11s 222us/step - loss: 1.0559 - acc: 0.7324 - val_loss: 1.1772 - val_acc: 0.7064
# Epoch 80/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0495 - acc: 0.7319 - val_loss: 1.2265 - val_acc: 0.6795
# Epoch 81/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0454 - acc: 0.7324 - val_loss: 1.4221 - val_acc: 0.6440
# Epoch 82/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0540 - acc: 0.7346 - val_loss: 1.0141 - val_acc: 0.7464
# Epoch 83/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0447 - acc: 0.7330 - val_loss: 1.2745 - val_acc: 0.6670
# Epoch 84/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0450 - acc: 0.7333 - val_loss: 1.7627 - val_acc: 0.5497
# Epoch 85/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0479 - acc: 0.7331 - val_loss: 1.1477 - val_acc: 0.7011
# Epoch 86/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.0421 - acc: 0.7354 - val_loss: 1.1101 - val_acc: 0.7227
# Epoch 87/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0406 - acc: 0.7326 - val_loss: 1.3376 - val_acc: 0.6574
# Epoch 88/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0372 - acc: 0.7347 - val_loss: 1.2144 - val_acc: 0.6641
# Epoch 89/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0409 - acc: 0.7338 - val_loss: 1.2343 - val_acc: 0.6823
# Epoch 90/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0394 - acc: 0.7323 - val_loss: 1.1027 - val_acc: 0.7202
# Epoch 91/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0346 - acc: 0.7358 - val_loss: 1.1202 - val_acc: 0.7279
# Epoch 92/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0359 - acc: 0.7351 - val_loss: 1.3043 - val_acc: 0.6613
# Epoch 93/200
# 50000/50000 [==============================] - 11s 221us/step - loss: 1.0344 - acc: 0.7350 - val_loss: 1.4959 - val_acc: 0.6057
# Epoch 94/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0330 - acc: 0.7345 - val_loss: 1.2915 - val_acc: 0.6534
# Epoch 95/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0362 - acc: 0.7341 - val_loss: 1.1633 - val_acc: 0.7016
# Epoch 96/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0303 - acc: 0.7360 - val_loss: 1.1752 - val_acc: 0.6930
# Epoch 97/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0394 - acc: 0.7330 - val_loss: 1.1765 - val_acc: 0.7058
# Epoch 98/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0347 - acc: 0.7348 - val_loss: 1.1070 - val_acc: 0.7124
# Epoch 99/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0302 - acc: 0.7370 - val_loss: 1.2904 - val_acc: 0.6670
# Epoch 100/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0350 - acc: 0.7353 - val_loss: 1.1285 - val_acc: 0.7172
# Epoch 101/200
# 50000/50000 [==============================] - 11s 222us/step - loss: 1.0283 - acc: 0.7350 - val_loss: 1.3137 - val_acc: 0.6552
# Epoch 102/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0316 - acc: 0.7382 - val_loss: 1.6721 - val_acc: 0.5105
# Epoch 103/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0272 - acc: 0.7376 - val_loss: 1.1681 - val_acc: 0.6947
# Epoch 104/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0304 - acc: 0.7348 - val_loss: 1.0813 - val_acc: 0.7126
# Epoch 105/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0329 - acc: 0.7326 - val_loss: 1.1831 - val_acc: 0.6840
# Epoch 106/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0279 - acc: 0.7373 - val_loss: 1.5931 - val_acc: 0.5474
# Epoch 107/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0299 - acc: 0.7381 - val_loss: 1.1094 - val_acc: 0.7124
# Epoch 108/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0300 - acc: 0.7372 - val_loss: 1.1522 - val_acc: 0.7116
# Epoch 109/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0283 - acc: 0.7362 - val_loss: 1.2473 - val_acc: 0.6687
# Epoch 110/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0279 - acc: 0.7351 - val_loss: 1.2804 - val_acc: 0.6924
# Epoch 111/200
# 50000/50000 [==============================] - 11s 216us/step - loss: 1.0273 - acc: 0.7370 - val_loss: 1.3760 - val_acc: 0.6484
# Epoch 112/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0243 - acc: 0.7382 - val_loss: 1.0367 - val_acc: 0.7298
# Epoch 113/200
# 50000/50000 [==============================] - 11s 216us/step - loss: 1.0234 - acc: 0.7365 - val_loss: 1.3150 - val_acc: 0.6656
# Epoch 114/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0276 - acc: 0.7361 - val_loss: 1.1005 - val_acc: 0.7064
# Epoch 115/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.0241 - acc: 0.7387 - val_loss: 1.0882 - val_acc: 0.7092
# Epoch 116/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0241 - acc: 0.7383 - val_loss: 1.5797 - val_acc: 0.6204
# Epoch 117/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0217 - acc: 0.7369 - val_loss: 1.2482 - val_acc: 0.6689
# Epoch 118/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0193 - acc: 0.7384 - val_loss: 1.2915 - val_acc: 0.6750
# Epoch 119/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0214 - acc: 0.7377 - val_loss: 1.0767 - val_acc: 0.7123
# Epoch 120/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0182 - acc: 0.7378 - val_loss: 1.3103 - val_acc: 0.6823
# Epoch 121/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.0150 - acc: 0.7389 - val_loss: 1.0598 - val_acc: 0.7228
# Epoch 122/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.0193 - acc: 0.7412 - val_loss: 1.3910 - val_acc: 0.6424
# Epoch 123/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0154 - acc: 0.7408 - val_loss: 1.2236 - val_acc: 0.6715
# Epoch 124/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0138 - acc: 0.7375 - val_loss: 1.5834 - val_acc: 0.5780
# Epoch 125/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0205 - acc: 0.7380 - val_loss: 1.2590 - val_acc: 0.6644
# Epoch 126/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0127 - acc: 0.7395 - val_loss: 1.7174 - val_acc: 0.6049
# Epoch 127/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0162 - acc: 0.7377 - val_loss: 1.1017 - val_acc: 0.7104
# Epoch 128/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0177 - acc: 0.7389 - val_loss: 0.9715 - val_acc: 0.7571
# Epoch 129/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.0155 - acc: 0.7391 - val_loss: 1.2669 - val_acc: 0.6706
# Epoch 130/200
# 50000/50000 [==============================] - 11s 220us/step - loss: 1.0116 - acc: 0.7392 - val_loss: 1.1211 - val_acc: 0.7141
# Epoch 131/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0154 - acc: 0.7417 - val_loss: 1.6986 - val_acc: 0.6912
# Epoch 132/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0140 - acc: 0.7419 - val_loss: 1.1698 - val_acc: 0.6911
# Epoch 133/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0120 - acc: 0.7429 - val_loss: 1.2618 - val_acc: 0.6552
# Epoch 134/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0133 - acc: 0.7409 - val_loss: 1.3028 - val_acc: 0.6529
# Epoch 135/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0096 - acc: 0.7419 - val_loss: 1.0719 - val_acc: 0.7337
# Epoch 136/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0150 - acc: 0.7411 - val_loss: 1.2752 - val_acc: 0.6754
# Epoch 137/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0109 - acc: 0.7417 - val_loss: 1.1170 - val_acc: 0.6994
# Epoch 138/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0187 - acc: 0.7388 - val_loss: 1.0898 - val_acc: 0.7137
# Epoch 139/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0104 - acc: 0.7416 - val_loss: 1.1690 - val_acc: 0.7078
# Epoch 140/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0070 - acc: 0.7422 - val_loss: 1.3972 - val_acc: 0.6604
# Epoch 141/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0108 - acc: 0.7412 - val_loss: 1.2302 - val_acc: 0.6664
# Epoch 142/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0100 - acc: 0.7409 - val_loss: 1.1993 - val_acc: 0.6871
# Epoch 143/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0066 - acc: 0.7411 - val_loss: 1.1317 - val_acc: 0.6955
# Epoch 144/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0113 - acc: 0.7421 - val_loss: 1.2385 - val_acc: 0.6801
# Epoch 145/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0113 - acc: 0.7410 - val_loss: 1.0740 - val_acc: 0.7158
# Epoch 146/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0063 - acc: 0.7429 - val_loss: 1.0244 - val_acc: 0.7396
# Epoch 147/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0078 - acc: 0.7426 - val_loss: 2.1817 - val_acc: 0.4656
# Epoch 148/200
# 50000/50000 [==============================] - 11s 216us/step - loss: 1.0107 - acc: 0.7431 - val_loss: 1.0361 - val_acc: 0.7332
# Epoch 149/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.0103 - acc: 0.7411 - val_loss: 1.1498 - val_acc: 0.7012
# Epoch 150/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0097 - acc: 0.7418 - val_loss: 1.1173 - val_acc: 0.7109
# Epoch 151/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0033 - acc: 0.7416 - val_loss: 1.3796 - val_acc: 0.6280
# Epoch 152/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0012 - acc: 0.7451 - val_loss: 1.1787 - val_acc: 0.6891
# Epoch 153/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0046 - acc: 0.7445 - val_loss: 1.1451 - val_acc: 0.7004
# Epoch 154/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0056 - acc: 0.7432 - val_loss: 1.2169 - val_acc: 0.6705
# Epoch 155/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0099 - acc: 0.7418 - val_loss: 1.2145 - val_acc: 0.6789
# Epoch 156/200
# 50000/50000 [==============================] - 11s 216us/step - loss: 1.0097 - acc: 0.7406 - val_loss: 1.0970 - val_acc: 0.7097
# Epoch 157/200
# 50000/50000 [==============================] - 11s 216us/step - loss: 1.0060 - acc: 0.7436 - val_loss: 1.0821 - val_acc: 0.7224
# Epoch 158/200
# 50000/50000 [==============================] - 11s 222us/step - loss: 1.0015 - acc: 0.7442 - val_loss: 1.4102 - val_acc: 0.6191
# Epoch 159/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.0052 - acc: 0.7427 - val_loss: 1.0997 - val_acc: 0.7031
# Epoch 160/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.0030 - acc: 0.7446 - val_loss: 1.1831 - val_acc: 0.6797
# Epoch 161/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0047 - acc: 0.7450 - val_loss: 1.1633 - val_acc: 0.6994
# Epoch 162/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.9994 - acc: 0.7451 - val_loss: 1.1739 - val_acc: 0.7006
# Epoch 163/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0046 - acc: 0.7435 - val_loss: 1.2975 - val_acc: 0.6480
# Epoch 164/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.0036 - acc: 0.7426 - val_loss: 1.0856 - val_acc: 0.7158
# Epoch 165/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0045 - acc: 0.7431 - val_loss: 1.1413 - val_acc: 0.6948
# Epoch 166/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0014 - acc: 0.7427 - val_loss: 1.3744 - val_acc: 0.6430
# Epoch 167/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.0070 - acc: 0.7408 - val_loss: 1.1543 - val_acc: 0.6975
# Epoch 168/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.9947 - acc: 0.7441 - val_loss: 1.1076 - val_acc: 0.7102
# Epoch 169/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0010 - acc: 0.7454 - val_loss: 1.6706 - val_acc: 0.5890
# Epoch 170/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.9994 - acc: 0.7427 - val_loss: 1.1679 - val_acc: 0.7071
# Epoch 171/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.9964 - acc: 0.7432 - val_loss: 1.1754 - val_acc: 0.7059
# Epoch 172/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.9961 - acc: 0.7461 - val_loss: 1.5865 - val_acc: 0.5797
# Epoch 173/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.9967 - acc: 0.7454 - val_loss: 1.2145 - val_acc: 0.6913
# Epoch 174/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.9987 - acc: 0.7436 - val_loss: 1.0992 - val_acc: 0.7057
# Epoch 175/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.9936 - acc: 0.7447 - val_loss: 1.1702 - val_acc: 0.6774
# Epoch 176/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.0027 - acc: 0.7423 - val_loss: 1.1192 - val_acc: 0.7032
# Epoch 177/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.9958 - acc: 0.7458 - val_loss: 1.1328 - val_acc: 0.7159
# Epoch 178/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.9930 - acc: 0.7444 - val_loss: 1.3236 - val_acc: 0.6548
# Epoch 179/200
# 50000/50000 [==============================] - 11s 216us/step - loss: 0.9951 - acc: 0.7451 - val_loss: 1.0597 - val_acc: 0.7263
# Epoch 180/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.9919 - acc: 0.7437 - val_loss: 1.1124 - val_acc: 0.6985
# Epoch 181/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.9966 - acc: 0.7461 - val_loss: 1.2163 - val_acc: 0.6664
# Epoch 182/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.9923 - acc: 0.7458 - val_loss: 1.1473 - val_acc: 0.6958
# Epoch 183/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.9971 - acc: 0.7437 - val_loss: 1.0244 - val_acc: 0.7397
# Epoch 184/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.9889 - acc: 0.7455 - val_loss: 1.4862 - val_acc: 0.6302
# Epoch 185/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 0.9910 - acc: 0.7471 - val_loss: 1.1226 - val_acc: 0.6970
# Epoch 186/200
# 50000/50000 [==============================] - 11s 219us/step - loss: 0.9899 - acc: 0.7443 - val_loss: 1.4232 - val_acc: 0.6048
# Epoch 187/200
# 50000/50000 [==============================] - 11s 220us/step - loss: 0.9917 - acc: 0.7463 - val_loss: 1.8426 - val_acc: 0.5358
# Epoch 188/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.9895 - acc: 0.7444 - val_loss: 1.2453 - val_acc: 0.6565
# Epoch 189/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.9902 - acc: 0.7444 - val_loss: 1.0394 - val_acc: 0.7384
# Epoch 190/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.9867 - acc: 0.7475 - val_loss: 1.1872 - val_acc: 0.6865
# Epoch 191/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.9924 - acc: 0.7444 - val_loss: 1.2049 - val_acc: 0.6969
# Epoch 192/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.9887 - acc: 0.7479 - val_loss: 1.4383 - val_acc: 0.6258
# Epoch 193/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.9899 - acc: 0.7465 - val_loss: 1.1250 - val_acc: 0.6964
# Epoch 194/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.9866 - acc: 0.7468 - val_loss: 1.1021 - val_acc: 0.7271
# Epoch 195/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.9894 - acc: 0.7450 - val_loss: 1.2896 - val_acc: 0.6615
# Epoch 196/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.9915 - acc: 0.7451 - val_loss: 1.0926 - val_acc: 0.7155
# Epoch 197/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.9889 - acc: 0.7463 - val_loss: 1.2078 - val_acc: 0.6703
# Epoch 198/200
# 50000/50000 [==============================] - 11s 218us/step - loss: 0.9885 - acc: 0.7455 - val_loss: 1.0158 - val_acc: 0.7341
# Epoch 199/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.9850 - acc: 0.7480 - val_loss: 1.3119 - val_acc: 0.6415
# Epoch 200/200
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.9851 - acc: 0.7479 - val_loss: 1.0290 - val_acc: 0.7385

# %% [markdown]
# ## Evaulating the model

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 1.0289634554862976
# Test accuracy: 0.7385

# %% [markdown]
# ## Prediction the model

# %%
y_pred = model.predict(x_test)

# %%
x_test
# Out:
# array([[[[0.61960787, 0.4392157 , 0.19215687],
#          [0.62352943, 0.43529412, 0.18431373],
#          [0.64705884, 0.45490196, 0.2       ],
#          ...,
#          [0.5372549 , 0.37254903, 0.14117648],
#          [0.49411765, 0.35686275, 0.14117648],
#          [0.45490196, 0.33333334, 0.12941177]],
#
#         [[0.59607846, 0.4392157 , 0.2       ],
#          [0.5921569 , 0.43137255, 0.15686275],
#          [0.62352943, 0.44705883, 0.1764706 ],
#          ...,
#          [0.53333336, 0.37254903, 0.12156863],
#          [0.49019608, 0.35686275, 0.1254902 ],
#          [0.46666667, 0.34509805, 0.13333334]],
#
#         [[0.5921569 , 0.43137255, 0.18431373],
#          [0.5921569 , 0.42745098, 0.12941177],
#          [0.61960787, 0.43529412, 0.14117648],
#          ...,
#          [0.54509807, 0.38431373, 0.13333334],
#          [0.50980395, 0.37254903, 0.13333334],
#          [0.47058824, 0.34901962, 0.12941177]],
#
#         ...,
#
#         [[0.26666668, 0.4862745 , 0.69411767],
#          [0.16470589, 0.39215687, 0.5803922 ],
#          [0.12156863, 0.34509805, 0.5372549 ],
#          ...,
#          [0.14901961, 0.38039216, 0.57254905],
#          [0.05098039, 0.2509804 , 0.42352942],
#          [0.15686275, 0.33333334, 0.49803922]],
#
#         [[0.23921569, 0.45490196, 0.65882355],
#          [0.19215687, 0.4       , 0.5803922 ],
#          [0.13725491, 0.33333334, 0.5176471 ],
#          ...,
#          [0.10196079, 0.32156864, 0.50980395],
#          [0.11372549, 0.32156864, 0.49411765],
#          [0.07843138, 0.2509804 , 0.41960785]],
#
#         [[0.21176471, 0.41960785, 0.627451  ],
#          [0.21960784, 0.4117647 , 0.58431375],
#          [0.1764706 , 0.34901962, 0.5176471 ],
#          ...,
#          [0.09411765, 0.3019608 , 0.4862745 ],
#          [0.13333334, 0.32941177, 0.5058824 ],
#          [0.08235294, 0.2627451 , 0.43137255]]],
#
#
#        [[[0.92156863, 0.92156863, 0.92156863],
#          [0.90588236, 0.90588236, 0.90588236],
#          [0.9098039 , 0.9098039 , 0.9098039 ],
#          ...,
#          [0.9137255 , 0.9137255 , 0.9137255 ],
#          [0.9137255 , 0.9137255 , 0.9137255 ],
#          [0.9098039 , 0.9098039 , 0.9098039 ]],
#
#         [[0.93333334, 0.93333334, 0.93333334],
#          [0.92156863, 0.92156863, 0.92156863],
#          [0.92156863, 0.92156863, 0.92156863],
#          ...,
#          [0.9254902 , 0.9254902 , 0.9254902 ],
#          [0.9254902 , 0.9254902 , 0.9254902 ],
#          [0.92156863, 0.92156863, 0.92156863]],
#
#         [[0.92941177, 0.92941177, 0.92941177],
#          [0.91764706, 0.91764706, 0.91764706],
#          [0.91764706, 0.91764706, 0.91764706],
#          ...,
#          [0.92156863, 0.92156863, 0.92156863],
#          [0.92156863, 0.92156863, 0.92156863],
#          [0.91764706, 0.91764706, 0.91764706]],
#
#         ...,
#
#         [[0.34117648, 0.3882353 , 0.34901962],
#          [0.16862746, 0.2       , 0.14509805],
#          [0.07450981, 0.09019608, 0.04313726],
#          ...,
#          [0.6627451 , 0.72156864, 0.7019608 ],
#          [0.7137255 , 0.77254903, 0.75686276],
#          [0.7372549 , 0.7921569 , 0.7882353 ]],
#
#         [[0.32156864, 0.3764706 , 0.32156864],
#          [0.18039216, 0.22352941, 0.14117648],
#          [0.14117648, 0.17254902, 0.08627451],
#          ...,
#          [0.68235296, 0.7411765 , 0.7176471 ],
#          [0.7254902 , 0.78431374, 0.76862746],
#          [0.73333335, 0.7921569 , 0.78431374]],
#
#         [[0.33333334, 0.39607844, 0.3254902 ],
#          [0.24313726, 0.29411766, 0.1882353 ],
#          [0.22745098, 0.2627451 , 0.14901961],
#          ...,
#          [0.65882355, 0.7176471 , 0.69803923],
#          [0.7058824 , 0.7647059 , 0.7490196 ],
#          [0.7294118 , 0.78431374, 0.78039217]]],
#
#
#        [[[0.61960787, 0.74509805, 0.87058824],
#          [0.61960787, 0.73333335, 0.85490197],
#          [0.54509807, 0.6509804 , 0.7607843 ],
#          ...,
#          [0.89411765, 0.90588236, 0.91764706],
#          [0.92941177, 0.9372549 , 0.9529412 ],
#          [0.93333334, 0.94509804, 0.9647059 ]],
#
#         [[0.6666667 , 0.78431374, 0.8980392 ],
#          [0.6745098 , 0.78039217, 0.8862745 ],
#          [0.5921569 , 0.6901961 , 0.7882353 ],
#          ...,
#          [0.9098039 , 0.9098039 , 0.9254902 ],
#          [0.9647059 , 0.9647059 , 0.98039216],
#          [0.9647059 , 0.96862745, 0.9843137 ]],
#
#         [[0.68235296, 0.7882353 , 0.88235295],
#          [0.6901961 , 0.78431374, 0.87058824],
#          [0.6156863 , 0.7019608 , 0.78039217],
#          ...,
#          [0.9019608 , 0.8980392 , 0.9098039 ],
#          [0.98039216, 0.9764706 , 0.9843137 ],
#          [0.9607843 , 0.95686275, 0.96862745]],
#
#         ...,
#
#         [[0.12156863, 0.15686275, 0.1764706 ],
#          [0.11764706, 0.15294118, 0.17254902],
#          [0.10196079, 0.13725491, 0.15686275],
#          ...,
#          [0.14509805, 0.15686275, 0.18039216],
#          [0.03529412, 0.05098039, 0.05490196],
#          [0.01568628, 0.02745098, 0.01960784]],
#
#         [[0.09019608, 0.13333334, 0.15294118],
#          [0.10588235, 0.14901961, 0.16862746],
#          [0.09803922, 0.14117648, 0.16078432],
#          ...,
#          [0.07450981, 0.07843138, 0.09411765],
#          [0.01568628, 0.02352941, 0.01176471],
#          [0.01960784, 0.02745098, 0.01176471]],
#
#         [[0.10980392, 0.16078432, 0.18431373],
#          [0.11764706, 0.16862746, 0.19607843],
#          [0.1254902 , 0.1764706 , 0.20392157],
#          ...,
#          [0.01960784, 0.02352941, 0.03137255],
#          [0.01568628, 0.01960784, 0.01176471],
#          [0.02745098, 0.03137255, 0.02745098]]],
#
#
#        ...,
#
#
#        [[[0.07843138, 0.05882353, 0.04705882],
#          [0.07450981, 0.05490196, 0.04313726],
#          [0.05882353, 0.05490196, 0.04313726],
#          ...,
#          [0.03921569, 0.03529412, 0.02745098],
#          [0.04705882, 0.04313726, 0.03529412],
#          [0.05098039, 0.04705882, 0.03921569]],
#
#         [[0.08235294, 0.0627451 , 0.05098039],
#          [0.07843138, 0.0627451 , 0.05098039],
#          [0.07058824, 0.06666667, 0.04705882],
#          ...,
#          [0.03921569, 0.03529412, 0.02745098],
#          [0.03921569, 0.03529412, 0.02745098],
#          [0.04705882, 0.04313726, 0.03529412]],
#
#         [[0.08235294, 0.0627451 , 0.05098039],
#          [0.08235294, 0.06666667, 0.04705882],
#          [0.07843138, 0.07058824, 0.04313726],
#          ...,
#          [0.04705882, 0.04313726, 0.03529412],
#          [0.04705882, 0.04313726, 0.03529412],
#          [0.05098039, 0.04705882, 0.03921569]],
#
#         ...,
#
#         [[0.12941177, 0.09803922, 0.05098039],
#          [0.13333334, 0.10196079, 0.05882353],
#          [0.13333334, 0.10196079, 0.05882353],
#          ...,
#          [0.10980392, 0.09803922, 0.20392157],
#          [0.11372549, 0.09803922, 0.22745098],
#          [0.09019608, 0.07843138, 0.16470589]],
#
#         [[0.12941177, 0.09803922, 0.05490196],
#          [0.13333334, 0.10196079, 0.05882353],
#          [0.13333334, 0.10196079, 0.05882353],
#          ...,
#          [0.10588235, 0.09411765, 0.20392157],
#          [0.10588235, 0.09411765, 0.21960784],
#          [0.09803922, 0.08627451, 0.18431373]],
#
#         [[0.12156863, 0.09019608, 0.04705882],
#          [0.1254902 , 0.09411765, 0.05098039],
#          [0.12941177, 0.09803922, 0.05490196],
#          ...,
#          [0.09411765, 0.09019608, 0.19607843],
#          [0.10196079, 0.09019608, 0.20784314],
#          [0.09803922, 0.07843138, 0.18431373]]],
#
#
#        [[[0.09803922, 0.15686275, 0.04705882],
#          [0.05882353, 0.14117648, 0.01176471],
#          [0.09019608, 0.16078432, 0.07058824],
#          ...,
#          [0.23921569, 0.32156864, 0.30588236],
#          [0.36078432, 0.44313726, 0.4392157 ],
#          [0.29411766, 0.34901962, 0.36078432]],
#
#         [[0.04705882, 0.09803922, 0.02352941],
#          [0.07843138, 0.14509805, 0.02745098],
#          [0.09411765, 0.14117648, 0.05882353],
#          ...,
#          [0.4509804 , 0.5254902 , 0.5411765 ],
#          [0.58431375, 0.65882355, 0.69411767],
#          [0.40784314, 0.45882353, 0.5137255 ]],
#
#         [[0.04705882, 0.09803922, 0.04313726],
#          [0.05882353, 0.11372549, 0.02352941],
#          [0.13333334, 0.15686275, 0.09411765],
#          ...,
#          [0.6039216 , 0.6745098 , 0.7137255 ],
#          [0.6156863 , 0.6862745 , 0.7529412 ],
#          [0.45490196, 0.5058824 , 0.5921569 ]],
#
#         ...,
#
#         [[0.39215687, 0.5058824 , 0.31764707],
#          [0.40392157, 0.5176471 , 0.32941177],
#          [0.40784314, 0.5254902 , 0.3372549 ],
#          ...,
#          [0.38039216, 0.5019608 , 0.32941177],
#          [0.38431373, 0.49411765, 0.32941177],
#          [0.35686275, 0.4745098 , 0.30980393]],
#
#         [[0.40392157, 0.5176471 , 0.3254902 ],
#          [0.40784314, 0.5137255 , 0.3254902 ],
#          [0.41960785, 0.5294118 , 0.34117648],
#          ...,
#          [0.39607844, 0.5176471 , 0.34117648],
#          [0.3882353 , 0.49803922, 0.32941177],
#          [0.36078432, 0.4745098 , 0.30980393]],
#
#         [[0.37254903, 0.49411765, 0.30588236],
#          [0.37254903, 0.48235294, 0.29803923],
#          [0.39607844, 0.5019608 , 0.31764707],
#          ...,
#          [0.3647059 , 0.4862745 , 0.3137255 ],
#          [0.37254903, 0.48235294, 0.31764707],
#          [0.36078432, 0.47058824, 0.3137255 ]]],
#
#
#        [[[0.28627452, 0.30588236, 0.29411766],
#          [0.38431373, 0.40392157, 0.44313726],
#          [0.3882353 , 0.41568628, 0.44705883],
#          ...,
#          [0.5294118 , 0.5882353 , 0.59607846],
#          [0.5294118 , 0.58431375, 0.6039216 ],
#          [0.79607844, 0.84313726, 0.8745098 ]],
#
#         [[0.27058825, 0.28627452, 0.27450982],
#          [0.32941177, 0.34901962, 0.38039216],
#          [0.26666668, 0.29411766, 0.31764707],
#          ...,
#          [0.33333334, 0.37254903, 0.34901962],
#          [0.2784314 , 0.32156864, 0.3137255 ],
#          [0.47058824, 0.52156866, 0.5294118 ]],
#
#         [[0.27058825, 0.28627452, 0.27450982],
#          [0.3529412 , 0.37254903, 0.39215687],
#          [0.24313726, 0.2784314 , 0.2901961 ],
#          ...,
#          [0.2901961 , 0.31764707, 0.27450982],
#          [0.20784314, 0.24313726, 0.21176471],
#          [0.24313726, 0.2901961 , 0.27058825]],
#
#         ...,
#
#         [[0.48235294, 0.5019608 , 0.3764706 ],
#          [0.5176471 , 0.5176471 , 0.4       ],
#          [0.5058824 , 0.5019608 , 0.39215687],
#          ...,
#          [0.42352942, 0.41960785, 0.34509805],
#          [0.24313726, 0.23529412, 0.21568628],
#          [0.10588235, 0.10588235, 0.10980392]],
#
#         [[0.4509804 , 0.4745098 , 0.35686275],
#          [0.48235294, 0.4862745 , 0.37254903],
#          [0.5058824 , 0.49411765, 0.3882353 ],
#          ...,
#          [0.4509804 , 0.45490196, 0.36862746],
#          [0.25882354, 0.25490198, 0.23137255],
#          [0.10588235, 0.10588235, 0.10588235]],
#
#         [[0.45490196, 0.47058824, 0.3529412 ],
#          [0.4745098 , 0.47843137, 0.36862746],
#          [0.5058824 , 0.5019608 , 0.39607844],
#          ...,
#          [0.45490196, 0.4509804 , 0.36862746],
#          [0.26666668, 0.25490198, 0.22745098],
#          [0.10588235, 0.10196079, 0.10196079]]]], dtype=float32)

# %%
plot_images(x=x_test[:25], y_true=y_test[:25], y_pred=y_pred[:25])

# %%
y_result = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
sns.heatmap(pd.DataFrame(y_result, range(10), range(10)), annot=True, fmt='g')

# %%
# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()


import matplotlib.pyplot as plt

# %%
# tbc.save_image(title="test_title", image=image)
